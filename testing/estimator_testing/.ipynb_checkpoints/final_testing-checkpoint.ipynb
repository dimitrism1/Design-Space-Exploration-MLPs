# %%
from tensorflow.keras.utils import to_categorical
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
import numpy as np
# %matplotlib inline
seed = 0
np.random.seed(seed)
import tensorflow as tf
tf.random.set_seed(seed)
import os


import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l1

from qkeras.qlayers import QDense, QActivation
from qkeras.quantizers import quantized_bits, quantized_relu
import tensorflow.compat.v1 as tf1
from qkeras.utils import model_save_quantized_weights

from tensorflow_model_optimization.python.core.sparsity.keras import prune, pruning_callbacks, pruning_schedule
from tensorflow_model_optimization.sparsity.keras import strip_pruning


from sklearn.preprocessing import OneHotEncoder,LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import random
import math


from tensorflow_model_optimization.python.core.sparsity.keras import prune, pruning_callbacks, pruning_schedule
from tensorflow_model_optimization.sparsity.keras import strip_pruning
from qkeras.utils import model_save_quantized_weights, load_qmodel
import hls4ml
import qkeras.utils

from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import r2_score

os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

# %%
from importlib import reload
import estimator as est
reload(est)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 3
#       1 from importlib import reload
#       2 import estimator as est
# ----> 3 import utils
#       4 reload(est)
#
# ModuleNotFoundError: No module named 'utils'

# %% [markdown]
# # # Gather all pretrained weights into an array to create a pool of weights and select from when testing the estimator

# %%
def generate_sparse(model,layer,l1,l2,sparsity):
    new = []
    with open("weight_pool.txt", 'r') as f:
        for lines in f:
            lines = float(lines)
            new.append(lines)
    new = np.array(new)
    bias = []
    with open("bias.txt", 'r') as f:
        for lines in f:
            lines = float(lines)
            bias.append(lines)
    bias = np.array(bias)
    
    zeros = np.zeros((int(l1*l2*sparsity),))
    x = np.array([])
    bias1 = np.array([])
    for i in range(int(l1*l2 - len(zeros))):
        random_index = random.randint(0,len(new) - 1)
        x = np.append(x,new[random_index])    
    y = np.concatenate((x,zeros))
    rng = np.random.default_rng()
    rng.shuffle(y)
    y = y.reshape(l1,l2)
    for i in range(l2):
        random_index_bias = random.randint(0,len(bias)-1)
        bias1 = np.append(bias1,bias[random_index_bias]) 
    model.weights[layer].assign(y)
    model.weights[layer + 1].assign(bias1)
    qkeras.utils.get_model_sparsity(model)
    return y

# %%
from testing_utils import generate_sparse
from importlib import reload
reload(testing_utils)
# Out:
# <module 'testing_utils' from '/home/dmitsas/Downloads/dse/testing/estimator_testing/testing_utils.py'>

# %%
id_num = 8
prec = 8
reuse = 1
#filename = "./sim_results/results/test_" + str(id_num) + "/model_"
filename = "./final_results/results/prec_" + str(prec) + "/reuse_" + str(reuse) + "/model_"
filename
# Out:
# './final_results/results/prec_8/reuse_1/model_'

# %%
rf_range = [1,2,3,4,10]

# %%
layer_num = 50
models = []
RF = []
precision = []
sparsity = []
selector = []
bits = 8
int_bits = 0
impl = {'LUT':0,'DSP':1}
select = 'DSP'
model_layers = [[] for x in range(layer_num)]
initialiser = tf.keras.initializers.lecun_uniform()
for prec in range(8,1,-1):
    x = 0
    for reuse in rf_range: 
        models = []
        RF = []
        precision = []
        sparsity = []
        selector = []
        filename = "./results_DSP/results/prec_" + str(prec) + "/reuse_" + str(reuse) + "/model_"
        for i in range(x,layer_num,1):  
                model = Sequential()
                layer_1 = random.randint(8,25)
                layer_2 = random.randint(4,60)                           
                layer_3 = random.randint(4,64)                          
                layer_4 = random.randint(8,40)
                model_layers[i].append(layer_1)
                model_layers[i].append(layer_2)
                model_layers[i].append(layer_3)
                model_layers[i].append(layer_4)
                
                model = Sequential()
                model.add(QDense(layer_2, input_shape=(layer_1,), name='fc1', kernel_quantizer=quantized_bits(bits,int_bits,alpha=1,use_stochastic_rounding=True),bias_quantizer=quantized_bits(bits,int_bits,alpha=1),
                                kernel_initializer=initialiser, kernel_regularizer=l1(0.0001)   ))
                model.add(QActivation(activation=quantized_relu(bits,int_bits,use_stochastic_rounding=False), name='relu1'))
                model.add(QDense(layer_3, name='fc2',
                                kernel_quantizer=quantized_bits(bits,int_bits,alpha=1,use_stochastic_rounding=True), bias_quantizer=quantized_bits(bits,int_bits,alpha=1),
                                kernel_initializer=initialiser, kernel_regularizer=l1(0.0001 ) ))
                model.add(QActivation(activation=quantized_relu(bits,int_bits,use_stochastic_rounding=False), name='relu2'))
                model.add(QDense(layer_4, name='fc3',
                                 kernel_quantizer=quantized_bits(bits,int_bits,alpha=1,use_stochastic_rounding=True), bias_quantizer=quantized_bits(bits,int_bits,alpha=1),
                                 kernel_initializer=initialiser, kernel_regularizer=l1(0.0001 ) ))
           
                model.add(Activation(activation='softmax', name='softmax'))
                sparsity.append(np.random.uniform(0.2,0.8))
                for layer in range(0,len(model.layers),2):
                    generate_sparse(model,layer,model.weights[layer].shape[0],model.weights[layer].shape[1],sparsity[i])

                models.append(model)
                model.save(filename + str(i) + "/KERAS_check_best_mode.h5")
                #RF.append(random.randint(1,3))
                #RF.append(1)
                selector.append(impl[select])
                RF.append(reuse)
                precision.append(prec)
                
                if not (os.path.exists(filename + str(i))):
                    os.makedirs(filename + str(i))
                with open(filename + str(i) + "/layers.txt",'w') as f:
                    f.write(str(model_layers[i][0]) + " " + str(model_layers[i][1]))
                    f.close
                with open(filename + str(i) + "/precision.txt",'w') as f:
                    f.write(str(precision[i]))
                    f.close

                with open(filename + str(i) + "/reuse.txt",'w') as f:
                    f.write(str(int(RF[i])))
                    f.close



                
                config = hls4ml.utils.config_from_keras_model(models[i],granularity='name')
                #config['Model']['Precision']='fixed<16,4>'
                config['LayerName']['fc1_input']['Precision']['result'] = 'fixed<' + str(precision[i]) + ',2>'
                config['LayerName']['relu1']['Precision']['result'] = 'ap_ufixed<' + str(precision[i]) + ',0,AP_RND_CONV,AP_SAT>'
                config['LayerName']['relu2']['Precision']['result'] = 'ap_ufixed<' + str(precision[i]) + ',0,AP_RND_CONV,AP_SAT>'
                #config['LayerName']['relu3']['Precision']['result'] = 'ap_ufixed<' + str(precision[i]) + ',0,AP_RND_CONV,AP_SAT>'

                #selector.append(random.randint(0,1))
                            #config['LayerName']['output']['Precision']['result'] = 'fixed<16,4>'
                config['LayerName']['softmax']['exp_table_t'] = 'ap_fixed<18,8>'
                config['LayerName']['softmax']['inv_table_t'] = 'ap_fixed<18,4>'
                config['Model']['ReuseFactor'] = RF[i]
                #config['LayerName']['fc1']['Precision']['result'] = 'fixed<16,4>'
                #config['LayerName']['fc2']['Precision']['result'] = 'fixed<16,4>'
                models[i].save(filename + str(i) + "/KERAS_check_best_mode.h5")
                hls_model = hls4ml.converters.convert_from_keras_model(
                    models[i],hls_config = config,output_dir = filename + str(i) + '/hls4ml_prj',part = 'xc7z007s-clg225-2')
                hls_model.compile()
                os.system('cp -r ./scripts/project_orig.tcl ./scripts/build_prj_orig.tcl ./scripts/init.sh ./scripts/build_prj_orig_lut.tcl ./scripts/init_lut.sh ' + filename + str(i) + '/hls4ml_prj')
                start_dir = os.getcwd()
                os.chdir(filename + str(i) + '/hls4ml_prj')
                if selector[i] == 0:
                    os.system('bash init_lut.sh')
                    os.system('rm init.sh')
                elif selector[i] == 1:
                    os.system('bash init.sh')
                    os.system('rm init_lut.sh')
                #os.chdir('/home/dmitsas/Downloads/notebooks/misc/')
                os.chdir(start_dir)
                if i==49:
                    for k in range(layer_num+1):
                        os.system("rm -r " + filename + str(k) + "/hls4ml_prj/myproject_prj/solution1/.autopilot")
                with open(filename + str(i) + "/impl.txt",'w') as f:
                    f.write(str(selector[i]))
                    f.close

for k in range(layer_num+1):
            os.system("rm -r " + filename + str(k) + "/hls4ml_prj/myproject_prj/solution1/.autopilot")
# Out:
# /home/dmitsas/anaconda3/envs/hls4ml-tutorial/lib/python3.10/site-packages/keras/initializers/initializers_v2.py:120: UserWarning: The initializer LecunUniform is unseeded and being called multiple times, which will return identical values  each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initalizer instance more than once.
#   warnings.warn(
# ... quantizing model
# ... quantizing model
# ... quantizing model
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Interpreting Sequential
# Topology:
# Layer name: fc1_input, layer type: InputLayer, input shapes: [[None, 19]], output shape: [None, 19]
# Layer name: fc1, layer type: QDense, input shapes: [[None, 19]], output shape: [None, 29]
# Layer name: relu1, layer type: Activation, input shapes: [[None, 29]], output shape: [None, 29]
# Layer name: fc2, layer type: QDense, input shapes: [[None, 29]], output shape: [None, 48]
# Layer name: relu2, layer type: Activation, input shapes: [[None, 48]], output shape: [None, 48]
# Layer name: fc3, layer type: QDense, input shapes: [[None, 48]], output shape: [None, 10]
# Layer name: softmax, layer type: Softmax, input shapes: [[None, 10]], output shape: [None, 10]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Interpreting Sequential
# Topology:
# Layer name: fc1_input, layer type: InputLayer, input shapes: [[None, 19]], output shape: [None, 19]
# Layer name: fc1, layer type: QDense, input shapes: [[None, 19]], output shape: [None, 29]
# Layer name: relu1, layer type: Activation, input shapes: [[None, 29]], output shape: [None, 29]
# Layer name: fc2, layer type: QDense, input shapes: [[None, 29]], output shape: [None, 48]
# Layer name: relu2, layer type: Activation, input shapes: [[None, 48]], output shape: [None, 48]
# Layer name: fc3, layer type: QDense, input shapes: [[None, 48]], output shape: [None, 10]
# Layer name: softmax, layer type: Softmax, input shapes: [[None, 10]], output shape: [None, 10]
# Creating HLS model
# Writing HLS project
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Done
#
# ****** Vitis HLS - High-Level Synthesis from C, C++ and OpenCL v2022.1 (64-bit)
#   **** SW Build 3526262 on Mon Apr 18 15:47:01 MDT 2022
#   **** IP Build 3524634 on Mon Apr 18 20:55:01 MDT 2022
#     ** Copyright 1986-2022 Xilinx, Inc. All Rights Reserved.
#
# source /tools/Xilinx/Vitis_HLS/2022.1/scripts/vitis_hls/hls.tcl -notrace
# INFO: [HLS 200-10] Running '/tools/Xilinx/Vitis_HLS/2022.1/bin/unwrapped/lnx64.o/vitis_hls'
# INFO: [HLS 200-10] For user 'dmitsas' on host 'skylla' (Linux_x86_64 version 5.4.0-196-generic) on Mon Sep 23 15:36:48 EEST 2024
# INFO: [HLS 200-10] On os Ubuntu 20.04 LTS
# INFO: [HLS 200-10] In directory '/home/dmitsas/Downloads/dse/testing/estimator_testing/results_DSP/results/prec_8/reuse_1/model_0/hls4ml_prj'
# Sourcing Tcl script 'build_prj_orig.tcl'
# INFO: [HLS 200-1510] Running: open_project myproject_prj
# INFO: [HLS 200-10] Creating and opening project '/home/dmitsas/Downloads/dse/testing/estimator_testing/results_DSP/results/prec_8/reuse_1/model_0/hls4ml_prj/myproject_prj'.
# INFO: [HLS 200-1510] Running: set_top myproject
# INFO: [HLS 200-1510] Running: add_files firmware/myproject.cpp -cflags -std=c++0x
# INFO: [HLS 200-10] Adding design file 'firmware/myproject.cpp' to the project
# INFO: [HLS 200-1510] Running: add_files -tb myproject_test.cpp -cflags -std=c++0x
# INFO: [HLS 200-10] Adding test bench file 'myproject_test.cpp' to the project
# INFO: [HLS 200-1510] Running: add_files -tb firmware/weights
# INFO: [HLS 200-10] Adding test bench file 'firmware/weights' to the project
# INFO: [HLS 200-1510] Running: add_files -tb tb_data
# INFO: [HLS 200-10] Adding test bench file 'tb_data' to the project
# INFO: [HLS 200-1510] Running: open_solution solution1
# INFO: [HLS 200-10] Creating and opening solution '/home/dmitsas/Downloads/dse/testing/estimator_testing/results_DSP/results/prec_8/reuse_1/model_0/hls4ml_prj/myproject_prj/solution1'.
# INFO: [HLS 200-1505] Using default flow_target 'vivado'
# Resolution: For help on HLS 200-1505 see www.xilinx.com/cgi-bin/docs/rdoc?v=2022.1;t=hls+guidance;d=200-1505.html
# INFO: [HLS 200-435] Setting 'open_solution -flow_target vivado' configuration: config_interface -m_axi_latency=0
# INFO: [HLS 200-1510] Running: config_array_partition -maximum_size 4096
# INFO: [XFORM 203-101] Allowed max sub elements number after partition is 4096.
# ERROR: [HLS 200-642] The 'config_array_partition -maximum_size' command is not supported.
# INFO: [HLS 200-1510] Running: config_compile -name_max_length 80
# INFO: [XFORM 203-1161] The maximum of name length is set to 80.
# INFO: [HLS 200-1510] Running: set_part xc7z007s-clg225-2
# INFO: [HLS 200-1611] Setting target device to 'xc7z007s-clg225-2'
# INFO: [XFORM 203-1161] The maximum of name length is set to 80.
# INFO: [HLS 200-1510] Running: config_schedule -enable_dsp_full_reg=false
# INFO: [HLS 200-1510] Running: config_op mul -impl dsp
# INFO: [HLS 200-1445] Configure operator 'mul' with implementation style 'dsp'.
# INFO: [HLS 200-1510] Running: create_clock -period 3.33 -name default
# INFO: [SYN 201-201] Setting up clock 'default' with a period of 3.33ns.
# INFO: [HLS 200-1510] Running: set_clock_uncertainty 12.5% default
# INFO: [SYN 201-201] Setting up clock 'default' with an uncertainty of 0.416ns.
# ***** C/RTL SYNTHESIS *****
# INFO: [HLS 200-1510] Running: csynth_design
# INFO: [HLS 200-111] Finished File checks and directory preparation: CPU user time: 0.01 seconds. CPU system time: 0 seconds. Elapsed time: 0.01 seconds; current allocated memory: 1.458 GB.
# INFO: [HLS 200-10] Analyzing design file 'firmware/myproject.cpp' ...
# WARNING: [HLS 207-5555] Unsupported interface port data type in '#pragma HLS interface ap_vld' (firmware/myproject.cpp:14:45)
# WARNING: [HLS 207-5292] unused parameter 'keep' (firmware/nnet_utils/nnet_helpers.h:285:99)
# WARNING: [HLS 207-5292] unused parameter 'data' (firmware/nnet_utils/nnet_code_gen.h:11:36)
# WARNING: [HLS 207-5292] unused parameter 'buffer' (firmware/nnet_utils/nnet_code_gen.h:12:36)
# WARNING: [HLS 207-5292] unused parameter 'partition' (firmware/nnet_utils/nnet_code_gen.h:13:44)
# WARNING: [HLS 207-5292] unused parameter 'data' (firmware/nnet_utils/nnet_code_gen.h:21:24)
# WARNING: [HLS 207-5292] unused parameter 'buffer' (firmware/nnet_utils/nnet_code_gen.h:22:24)
# WARNING: [HLS 207-5292] unused parameter 'partition' (firmware/nnet_utils/nnet_code_gen.h:23:32)
# INFO: [HLS 200-111] Finished Source Code Analysis and Preprocessing: CPU user time: 9.74 seconds. CPU system time: 0.92 seconds. Elapsed time: 9.83 seconds; current allocated memory: 464.637 MB.
# INFO: [HLS 200-777] Using interface defaults for 'Vivado' flow target.
# INFO: [HLS 214-131] Inlining function 'nnet::product::mult<ap_fixed<8, 2, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0> >::product(ap_fixed<8, 2, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>)' into 'void nnet::dense_latency<ap_fixed<8, 2, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>(ap_fixed<8, 2, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>*, config2::weight_t*, config2::bias_t*)' (firmware/nnet_utils/nnet_dense_latency.h:42:27)
# INFO: [HLS 214-131] Inlining function 'nnet::product::mult<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0> >::product(ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>)' into 'void nnet::dense_latency<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config5>(ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>*, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>*, config5::weight_t*, config5::bias_t*)' (firmware/nnet_utils/nnet_dense_latency.h:42:27)
# INFO: [HLS 214-131] Inlining function 'nnet::product::mult<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0> >::product(ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<8, 1, (ap_q_mode)5, (ap_o_mode)3, 0>)' into 'void nnet::dense_latency<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config8>(ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>*, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>*, config8::weight_t*, config8::bias_t*)' (firmware/nnet_utils/nnet_dense_latency.h:42:27)
# INFO: [HLS 214-131] Inlining function 'void nnet::dense<ap_fixed<8, 2, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>(ap_fixed<8, 2, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>*, config2::weight_t*, config2::bias_t*)' into 'myproject(ap_fixed<8, 2, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>*)' (firmware/myproject.cpp:39:2)
# INFO: [HLS 214-131] Inlining function 'void nnet::dense<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config5>(ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>*, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>*, config5::weight_t*, config5::bias_t*)' into 'myproject(ap_fixed<8, 2, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>*)' (firmware/myproject.cpp:47:2)
# INFO: [HLS 214-131] Inlining function 'void nnet::dense<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config8>(ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>*, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>*, config8::weight_t*, config8::bias_t*)' into 'myproject(ap_fixed<8, 2, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>*)' (firmware/myproject.cpp:55:2)
# INFO: [HLS 214-131] Inlining function 'void nnet::softmax<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, softmax_config10>(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>*)' into 'myproject(ap_fixed<8, 2, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>*)' (firmware/myproject.cpp:57:5)
# INFO: [HLS 214-291] Loop 'anonymous' is marked as complete unroll implied by the pipeline pragma (firmware/myproject.cpp:53:14)
# INFO: [HLS 214-291] Loop 'anonymous' is marked as complete unroll implied by the pipeline pragma (firmware/myproject.cpp:49:14)
# INFO: [HLS 214-291] Loop 'anonymous' is marked as complete unroll implied by the pipeline pragma (firmware/myproject.cpp:45:14)
# INFO: [HLS 214-291] Loop 'anonymous' is marked as complete unroll implied by the pipeline pragma (firmware/myproject.cpp:41:14)
# INFO: [HLS 214-291] Loop 'anonymous' is marked as complete unroll implied by the pipeline pragma (firmware/myproject.cpp:37:11)
# INFO: [HLS 214-291] Loop 'VITIS_LOOP_266_3' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_activation.h:266:23)
# INFO: [HLS 214-291] Loop 'VITIS_LOOP_252_2' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_activation.h:252:23)
# INFO: [HLS 214-291] Loop 'anonymous' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_activation.h:249:36)
# INFO: [HLS 214-291] Loop 'VITIS_LOOP_243_1' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_activation.h:243:23)
# INFO: [HLS 214-291] Loop 'anonymous' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_activation.h:242:61)
# INFO: [HLS 214-291] Loop 'anonymous' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_activation.h:222:36)
# INFO: [HLS 214-291] Loop 'anonymous' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_activation.h:221:36)
# INFO: [HLS 214-291] Loop 'Result' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_dense_latency.h:64:5)
# INFO: [HLS 214-291] Loop 'Accum1' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_dense_latency.h:54:5)
# INFO: [HLS 214-291] Loop 'Accum2' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_dense_latency.h:56:9)
# INFO: [HLS 214-291] Loop 'ResetAccum' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_dense_latency.h:48:5)
# INFO: [HLS 214-291] Loop 'Product1' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_dense_latency.h:37:5)
# INFO: [HLS 214-291] Loop 'Product2' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_dense_latency.h:40:9)
# INFO: [HLS 214-291] Loop 'anonymous' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_dense_latency.h:18:32)
# INFO: [HLS 214-291] Loop 'anonymous' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_dense_latency.h:17:32)
# INFO: [HLS 214-291] Loop 'VITIS_LOOP_43_1' is marked as complete unroll implied by the pipeline pragma (firmware/nnet_utils/nnet_activation.h:43:22)
# INFO: [HLS 214-186] Unrolling loop 'anonymous' (firmware/myproject.cpp:53:14) in function 'myproject' completely with a factor of 10 (firmware/myproject.cpp:9:0)
# INFO: [HLS 214-186] Unrolling loop 'anonymous' (firmware/myproject.cpp:49:14) in function 'myproject' completely with a factor of 48 (firmware/myproject.cpp:9:0)
# INFO: [HLS 214-186] Unrolling loop 'anonymous' (firmware/myproject.cpp:45:14) in function 'myproject' completely with a factor of 48 (firmware/myproject.cpp:9:0)
# INFO: [HLS 214-186] Unrolling loop 'anonymous' (firmware/myproject.cpp:41:14) in function 'myproject' completely with a factor of 29 (firmware/myproject.cpp:9:0)
# INFO: [HLS 214-186] Unrolling loop 'anonymous' (firmware/myproject.cpp:37:11) in function 'myproject' completely with a factor of 29 (firmware/myproject.cpp:9:0)
# INFO: [HLS 214-186] Unrolling loop 'VITIS_LOOP_266_3' (firmware/nnet_utils/nnet_activation.h:266:23) in function 'nnet::softmax_stable<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, softmax_config10>' completely with a factor of 10 (firmware/nnet_utils/nnet_activation.h:216:0)
# INFO: [HLS 214-186] Unrolling loop 'VITIS_LOOP_252_2' (firmware/nnet_utils/nnet_activation.h:252:23) in function 'nnet::softmax_stable<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, softmax_config10>' completely with a factor of 10 (firmware/nnet_utils/nnet_activation.h:216:0)
# INFO: [HLS 214-186] Unrolling loop 'anonymous' (firmware/nnet_utils/nnet_activation.h:249:36) in function 'nnet::softmax_stable<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, softmax_config10>' completely with a factor of 10 (firmware/nnet_utils/nnet_activation.h:216:0)
# INFO: [HLS 214-186] Unrolling loop 'VITIS_LOOP_243_1' (firmware/nnet_utils/nnet_activation.h:243:23) in function 'nnet::softmax_stable<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, softmax_config10>' completely with a factor of 10 (firmware/nnet_utils/nnet_activation.h:216:0)
# INFO: [HLS 214-186] Unrolling loop 'anonymous' (firmware/nnet_utils/nnet_activation.h:242:61) in function 'nnet::softmax_stable<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, softmax_config10>' completely with a factor of 10 (firmware/nnet_utils/nnet_activation.h:216:0)
# INFO: [HLS 214-186] Unrolling loop 'anonymous' (firmware/nnet_utils/nnet_activation.h:222:36) in function 'nnet::softmax_stable<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, softmax_config10>' completely with a factor of 1024 (firmware/nnet_utils/nnet_activation.h:216:0)
# INFO: [HLS 214-186] Unrolling loop 'anonymous' (firmware/nnet_utils/nnet_activation.h:221:36) in function 'nnet::softmax_stable<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, softmax_config10>' completely with a factor of 1024 (firmware/nnet_utils/nnet_activation.h:216:0)
# INFO: [HLS 214-186] Unrolling loop 'Result' (firmware/nnet_utils/nnet_dense_latency.h:64:5) in function 'nnet::dense_latency<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config8>' completely with a factor of 10 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'Accum1' (firmware/nnet_utils/nnet_dense_latency.h:54:5) in function 'nnet::dense_latency<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config8>' completely with a factor of 48 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'Accum2' (firmware/nnet_utils/nnet_dense_latency.h:56:9) in function 'nnet::dense_latency<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config8>' completely with a factor of 10 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'ResetAccum' (firmware/nnet_utils/nnet_dense_latency.h:48:5) in function 'nnet::dense_latency<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config8>' completely with a factor of 10 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'Product1' (firmware/nnet_utils/nnet_dense_latency.h:37:5) in function 'nnet::dense_latency<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config8>' completely with a factor of 48 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'Product2' (firmware/nnet_utils/nnet_dense_latency.h:40:9) in function 'nnet::dense_latency<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config8>' completely with a factor of 10 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'anonymous' (firmware/nnet_utils/nnet_dense_latency.h:18:32) in function 'nnet::dense_latency<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config8>' completely with a factor of 10 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'anonymous' (firmware/nnet_utils/nnet_dense_latency.h:17:32) in function 'nnet::dense_latency<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config8>' completely with a factor of 480 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'VITIS_LOOP_43_1' (firmware/nnet_utils/nnet_activation.h:43:22) in function 'nnet::relu<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, relu_config7>' completely with a factor of 48 (firmware/nnet_utils/nnet_activation.h:39:0)
# INFO: [HLS 214-186] Unrolling loop 'Result' (firmware/nnet_utils/nnet_dense_latency.h:64:5) in function 'nnet::dense_latency<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config5>' completely with a factor of 48 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'Accum1' (firmware/nnet_utils/nnet_dense_latency.h:54:5) in function 'nnet::dense_latency<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config5>' completely with a factor of 29 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'Accum2' (firmware/nnet_utils/nnet_dense_latency.h:56:9) in function 'nnet::dense_latency<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config5>' completely with a factor of 48 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'ResetAccum' (firmware/nnet_utils/nnet_dense_latency.h:48:5) in function 'nnet::dense_latency<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config5>' completely with a factor of 48 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'Product1' (firmware/nnet_utils/nnet_dense_latency.h:37:5) in function 'nnet::dense_latency<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config5>' completely with a factor of 29 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'Product2' (firmware/nnet_utils/nnet_dense_latency.h:40:9) in function 'nnet::dense_latency<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config5>' completely with a factor of 48 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'anonymous' (firmware/nnet_utils/nnet_dense_latency.h:18:32) in function 'nnet::dense_latency<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config5>' completely with a factor of 48 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'anonymous' (firmware/nnet_utils/nnet_dense_latency.h:17:32) in function 'nnet::dense_latency<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config5>' completely with a factor of 1392 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'VITIS_LOOP_43_1' (firmware/nnet_utils/nnet_activation.h:43:22) in function 'nnet::relu<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, relu_config4>' completely with a factor of 29 (firmware/nnet_utils/nnet_activation.h:39:0)
# INFO: [HLS 214-186] Unrolling loop 'Result' (firmware/nnet_utils/nnet_dense_latency.h:64:5) in function 'nnet::dense_latency<ap_fixed<8, 2, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>' completely with a factor of 29 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'Accum1' (firmware/nnet_utils/nnet_dense_latency.h:54:5) in function 'nnet::dense_latency<ap_fixed<8, 2, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>' completely with a factor of 19 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'Accum2' (firmware/nnet_utils/nnet_dense_latency.h:56:9) in function 'nnet::dense_latency<ap_fixed<8, 2, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>' completely with a factor of 29 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'ResetAccum' (firmware/nnet_utils/nnet_dense_latency.h:48:5) in function 'nnet::dense_latency<ap_fixed<8, 2, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>' completely with a factor of 29 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'Product1' (firmware/nnet_utils/nnet_dense_latency.h:37:5) in function 'nnet::dense_latency<ap_fixed<8, 2, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>' completely with a factor of 19 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'Product2' (firmware/nnet_utils/nnet_dense_latency.h:40:9) in function 'nnet::dense_latency<ap_fixed<8, 2, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>' completely with a factor of 29 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'anonymous' (firmware/nnet_utils/nnet_dense_latency.h:18:32) in function 'nnet::dense_latency<ap_fixed<8, 2, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>' completely with a factor of 29 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-186] Unrolling loop 'anonymous' (firmware/nnet_utils/nnet_dense_latency.h:17:32) in function 'nnet::dense_latency<ap_fixed<8, 2, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>' completely with a factor of 551 (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-178] Inlining function 'std::enable_if<!(std::is_same<ap_fixed<8, 2, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_uint<1> >::value), ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >::type nnet::cast<ap_fixed<8, 2, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>(config2::accum_t)' into 'void nnet::dense_latency<ap_fixed<8, 2, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>(ap_fixed<8, 2, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>*, config2::weight_t*, config2::bias_t*)' (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-178] Inlining function 'std::enable_if<!(std::is_same<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_uint<1> >::value), ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >::type nnet::cast<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config8>(config8::accum_t)' into 'void nnet::dense_latency<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config8>(ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>*, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>*, config8::weight_t*, config8::bias_t*)' (firmware/nnet_utils/nnet_dense_latency.h:15:0)
# INFO: [HLS 214-178] Inlining function 'nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >::operator()(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>)' into 'ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> nnet::reduce<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 2, nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> > >(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> const*, nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >) (.143.159.165)' (firmware/nnet_utils/nnet_common.h:36:0)
# INFO: [HLS 214-178] Inlining function 'ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> nnet::reduce<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 2, nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> > >(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> const*, nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >) (.143.159.165)' into 'ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> nnet::reduce<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 4, nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> > >(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> const*, nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >)' (firmware/nnet_utils/nnet_common.h:36:0)
# INFO: [HLS 214-178] Inlining function 'nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >::operator()(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>)' into 'ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> nnet::reduce<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 4, nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> > >(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> const*, nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >)' (firmware/nnet_utils/nnet_common.h:36:0)
# INFO: [HLS 214-178] Inlining function 'ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> nnet::reduce<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 4, nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> > >(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> const*, nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >)' into 'ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> nnet::reduce<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 8, nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> > >(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> const*, nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >)' (firmware/nnet_utils/nnet_common.h:36:0)
# INFO: [HLS 214-178] Inlining function 'nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >::operator()(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>)' into 'ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> nnet::reduce<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 8, nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> > >(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> const*, nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >)' (firmware/nnet_utils/nnet_common.h:36:0)
# INFO: [HLS 214-178] Inlining function 'ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> nnet::reduce<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 8, nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> > >(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> const*, nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >)' into 'ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> nnet::reduce<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 10, nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> > >(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> const*, nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >)' (firmware/nnet_utils/nnet_common.h:36:0)
# INFO: [HLS 214-178] Inlining function 'ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> nnet::reduce<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 2, nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> > >(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> const*, nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >) (.143.159.165)' into 'ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> nnet::reduce<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 10, nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> > >(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> const*, nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >)' (firmware/nnet_utils/nnet_common.h:36:0)
# INFO: [HLS 214-178] Inlining function 'nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >::operator()(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>) (.130)' into 'ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> nnet::reduce<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 10, nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> > >(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> const*, nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> >)' (firmware/nnet_utils/nnet_common.h:36:0)
# INFO: [HLS 214-178] Inlining function 'nnet::Op_add<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0> >::operator()(ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0>) (.21.42.48.56)' into 'ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0> nnet::reduce<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0>, 2, nnet::Op_add<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0> > >(ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0> const*, nnet::Op_add<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0> >) (.103.116.121)' (firmware/nnet_utils/nnet_common.h:36:0)
# INFO: [HLS 214-178] Inlining function 'ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0> nnet::reduce<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0>, 2, nnet::Op_add<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0> > >(ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0> const*, nnet::Op_add<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0> >) (.103.116.121)' into 'ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0> nnet::reduce<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0>, 4, nnet::Op_add<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0> > >(ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0> const*, nnet::Op_add<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0> >)' (firmware/nnet_utils/nnet_common.h:36:0)
# INFO: [HLS 214-178] Inlining function 'nnet::Op_add<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0> >::operator()(ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0>) (.21.42.48.56)' into 'ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0> nnet::reduce<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0>, 4, nnet::Op_add<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0> > >(ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0> const*, nnet::Op_add<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0> >)' (firmware/nnet_utils/nnet_common.h:36:0)
# INFO: [HLS 214-178] Inlining function 'nnet::Op_add<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0> >::operator()(ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0>) (.21.42.48.56)' into 'ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0> nnet::reduce<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0>, 8, nnet::Op_add<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0> > >(ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0> const*, nnet::Op_add<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0> >)' (firmware/nnet_utils/nnet_common.h:36:0)
# INFO: [HLS 214-178] Inlining function 'ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0> nnet::reduce<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0>, 8, nnet::Op_add<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0> > >(ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0> const*, nnet::Op_add<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0> >)' into 'ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0> nnet::reduce<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0>, 10, nnet::Op_add<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0> > >(ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0> const*, nnet::Op_add<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0> >)' (firmware/nnet_utils/nnet_common.h:36:0)
# INFO: [HLS 214-178] Inlining function 'ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0> nnet::reduce<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0>, 2, nnet::Op_add<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0> > >(ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0> const*, nnet::Op_add<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0> >) (.103.116.121)' into 'ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0> nnet::reduce<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0>, 10, nnet::Op_add<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0> > >(ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0> const*, nnet::Op_add<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0> >)' (firmware/nnet_utils/nnet_common.h:36:0)
# INFO: [HLS 214-178] Inlining function 'nnet::Op_add<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0> >::operator()(ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0>) (.21.42.48.56)' into 'ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0> nnet::reduce<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0>, 10, nnet::Op_add<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0> > >(ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0> const*, nnet::Op_add<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0> >)' (firmware/nnet_utils/nnet_common.h:36:0)
# INFO: [HLS 214-178] Inlining function 'unsigned int nnet::softmax_idx_from_real_val<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, softmax_config10>(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>)' into 'void nnet::softmax_stable<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, softmax_config10>(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>*)' (firmware/nnet_utils/nnet_activation.h:216:0)
# INFO: [HLS 214-178] Inlining function 'ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0> nnet::reduce<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0>, 10, nnet::Op_add<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0> > >(ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0> const*, nnet::Op_add<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0> >)' into 'void nnet::softmax_stable<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, softmax_config10>(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>*)' (firmware/nnet_utils/nnet_activation.h:216:0)
# INFO: [HLS 214-178] Inlining function 'unsigned int nnet::softmax_idx_from_real_val<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0>, softmax_config10>(ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0>)' into 'void nnet::softmax_stable<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, softmax_config10>(ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>*, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>*)' (firmware/nnet_utils/nnet_activation.h:216:0)
# INFO: [HLS 214-248] Applying array_partition to 'b8': Complete partitioning on dimension 1. (firmware/weights/b8.h:12:0)
# INFO: [HLS 214-248] Applying array_partition to 'b5': Complete partitioning on dimension 1. (firmware/weights/b5.h:12:0)
# INFO: [HLS 214-248] Applying array_partition to 'b2': Complete partitioning on dimension 1. (firmware/weights/b2.h:12:0)
# INFO: [HLS 214-248] Applying array_partition to 'mult': Complete partitioning on dimension 1. (firmware/nnet_utils/nnet_dense_latency.h:17:32)
# INFO: [HLS 214-248] Applying array_partition to 'acc': Complete partitioning on dimension 1. (firmware/nnet_utils/nnet_dense_latency.h:18:32)
# INFO: [HLS 214-248] Applying array_partition to 'exp_res': Complete partitioning on dimension 1. (firmware/nnet_utils/nnet_activation.h:249:36)
# INFO: [HLS 214-248] Applying array_partition to 'layer2_out': Complete partitioning on dimension 1. (firmware/myproject.cpp:37:11)
# INFO: [HLS 214-248] Applying array_partition to 'layer4_out': Complete partitioning on dimension 1. (firmware/myproject.cpp:41:14)
# INFO: [HLS 214-248] Applying array_partition to 'layer5_out': Complete partitioning on dimension 1. (firmware/myproject.cpp:45:14)
# INFO: [HLS 214-248] Applying array_partition to 'layer7_out': Complete partitioning on dimension 1. (firmware/myproject.cpp:49:14)
# INFO: [HLS 214-248] Applying array_partition to 'layer8_out': Complete partitioning on dimension 1. (firmware/myproject.cpp:53:14)
# INFO: [HLS 214-248] Applying array_partition to 'layer10_out': Complete partitioning on dimension 1. (firmware/myproject.cpp:9:0)
# INFO: [HLS 214-241] Aggregating scalar variable 'layer10_out_9' with compact=bit mode in 16-bits (firmware/myproject.cpp:9:0)
# INFO: [HLS 214-241] Aggregating scalar variable 'layer10_out_8' with compact=bit mode in 16-bits (firmware/myproject.cpp:9:0)
# INFO: [HLS 214-241] Aggregating scalar variable 'layer10_out_7' with compact=bit mode in 16-bits (firmware/myproject.cpp:9:0)
# INFO: [HLS 214-241] Aggregating scalar variable 'layer10_out_6' with compact=bit mode in 16-bits (firmware/myproject.cpp:9:0)
# INFO: [HLS 214-241] Aggregating scalar variable 'layer10_out_5' with compact=bit mode in 16-bits (firmware/myproject.cpp:9:0)
# INFO: [HLS 214-241] Aggregating scalar variable 'layer10_out_4' with compact=bit mode in 16-bits (firmware/myproject.cpp:9:0)
# INFO: [HLS 214-241] Aggregating scalar variable 'layer10_out_3' with compact=bit mode in 16-bits (firmware/myproject.cpp:9:0)
# INFO: [HLS 214-241] Aggregating scalar variable 'layer10_out_2' with compact=bit mode in 16-bits (firmware/myproject.cpp:9:0)
# INFO: [HLS 214-241] Aggregating scalar variable 'layer10_out_1' with compact=bit mode in 16-bits (firmware/myproject.cpp:9:0)
# INFO: [HLS 214-241] Aggregating scalar variable 'layer10_out_0' with compact=bit mode in 16-bits (firmware/myproject.cpp:9:0)
# INFO: [HLS 214-241] Aggregating bram variable 'fc1_input' with compact=bit mode in 8-bits (firmware/myproject.cpp:9:0)
# INFO: [HLS 214-248] Applying array_reshape to 'fc1_input': Complete reshaping on dimension 1. (firmware/myproject.cpp:9:0)
# INFO: [HLS 200-111] Finished Compiling Optimization and Transform: CPU user time: 50.52 seconds. CPU system time: 1.13 seconds. Elapsed time: 51.66 seconds; current allocated memory: 468.086 MB.
# INFO: [HLS 200-111] Finished Checking Pragmas: CPU user time: 0 seconds. CPU system time: 0 seconds. Elapsed time: 0 seconds; current allocated memory: 468.086 MB.
# INFO: [HLS 200-10] Starting code transformations ...
# INFO: [HLS 200-111] Finished Standard Transforms: CPU user time: 1.25 seconds. CPU system time: 0.07 seconds. Elapsed time: 1.32 seconds; current allocated memory: 625.781 MB.
# INFO: [HLS 200-10] Checking synthesizability ...
# INFO: [XFORM 203-602] Inlining function 'nnet::cast<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config5>' into 'nnet::dense_latency<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config5>' (firmware/nnet_utils/nnet_dense_latency.h:66) automatically.
# INFO: [XFORM 203-602] Inlining function 'nnet::reduce<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, 10, nnet::Op_max<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0> > >' into 'nnet::softmax_stable<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, softmax_config10>' (firmware/nnet_utils/nnet_activation.h:239) automatically.
# INFO: [XFORM 203-602] Inlining function 'nnet::reduce<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0>, 4, nnet::Op_add<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0> > >' into 'nnet::softmax_stable<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, softmax_config10>' (firmware/nnet_utils/nnet_common.h:45) automatically.
# INFO: [HLS 200-111] Finished Checking Synthesizability: CPU user time: 1.33 seconds. CPU system time: 0.04 seconds. Elapsed time: 1.38 seconds; current allocated memory: 759.527 MB.
# INFO: [XFORM 203-602] Inlining function 'nnet::cast<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config5>' into 'nnet::dense_latency<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config5>' (firmware/nnet_utils/nnet_dense_latency.h:66) automatically.
# INFO: [XFORM 203-602] Inlining function 'nnet::reduce<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0>, 4, nnet::Op_add<ap_fixed<18, 8, (ap_q_mode)5, (ap_o_mode)3, 0> > >' into 'nnet::softmax_stable<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, softmax_config10>' (firmware/nnet_utils/nnet_common.h:45) automatically.
# INFO: [XFORM 203-401] Performing if-conversion on hyperblock from (firmware/nnet_utils/nnet_activation.h:40:9) to (firmware/nnet_utils/nnet_activation.h:50:1) in function 'nnet::relu<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, relu_config7>'... converting 193 basic blocks.
# INFO: [XFORM 203-401] Performing if-conversion on hyperblock from (firmware/nnet_utils/nnet_activation.h:40:9) to (firmware/nnet_utils/nnet_activation.h:50:1) in function 'nnet::relu<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, relu_config4>'... converting 117 basic blocks.
# INFO: [XFORM 203-11] Balancing expressions in function 'nnet::softmax_stable<ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, softmax_config10>' (firmware/nnet_utils/nnet_activation.h:65:1)...9 expression(s) balanced.
# INFO: [XFORM 203-11] Balancing expressions in function 'nnet::dense_latency<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config8>' (firmware/nnet_utils/nnet_dense_latency.h:33:1)...261 expression(s) balanced.
# INFO: [XFORM 203-11] Balancing expressions in function 'nnet::dense_latency<ap_ufixed<8, 0, (ap_q_mode)4, (ap_o_mode)0, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config5>' (firmware/nnet_utils/nnet_dense_latency.h:33:1)...752 expression(s) balanced.
# INFO: [XFORM 203-11] Balancing expressions in function 'nnet::dense_latency<ap_fixed<8, 2, (ap_q_mode)5, (ap_o_mode)3, 0>, ap_fixed<16, 6, (ap_q_mode)5, (ap_o_mode)3, 0>, config2>' (firmware/nnet_utils/nnet_dense_latency.h:33:1)...299 expression(s) balanced.
# INFO: [HLS 200-111] Finished Loop, function and other optimizations: CPU user time: 2.4 seconds. CPU system time: 0.12 seconds. Elapsed time: 2.53 seconds; current allocated memory: 963.309 MB.
# INFO: [HLS 200-111] Finished Architecture Synthesis: CPU user time: 1.61 seconds. CPU system time: 0.09 seconds. Elapsed time: 1.68 seconds; current allocated memory: 1.072 GB.
# INFO: [HLS 200-10] Starting hardware synthesis ...
# INFO: [HLS 200-10] Synthesizing 'myproject' ...
# WARNING: [SYN 201-103] Legalizing function name 'dense_latency<ap_fixed<8, 2, 5, 3, 0>, ap_fixed<16, 6, 5, 3, 0>, config2>' to 'dense_latency_ap_fixed_8_2_5_3_0_ap_fixed_16_6_5_3_0_config2_s'.
# WARNING: [SYN 201-103] Legalizing function name 'relu<ap_fixed<16, 6, 5, 3, 0>, ap_ufixed<8, 0, 4, 0, 0>, relu_config4>' to 'relu_ap_fixed_16_6_5_3_0_ap_ufixed_8_0_4_0_0_relu_config4_s'.
# WARNING: [SYN 201-103] Legalizing function name 'dense_latency<ap_ufixed<8, 0, 4, 0, 0>, ap_fixed<16, 6, 5, 3, 0>, config5>' to 'dense_latency_ap_ufixed_8_0_4_0_0_ap_fixed_16_6_5_3_0_config5_s'.
# WARNING: [SYN 201-103] Legalizing function name 'relu<ap_fixed<16, 6, 5, 3, 0>, ap_ufixed<8, 0, 4, 0, 0>, relu_config7>' to 'relu_ap_fixed_16_6_5_3_0_ap_ufixed_8_0_4_0_0_relu_config7_s'.
# WARNING: [SYN 201-103] Legalizing function name 'dense_latency<ap_ufixed<8, 0, 4, 0, 0>, ap_fixed<16, 6, 5, 3, 0>, config8>' to 'dense_latency_ap_ufixed_8_0_4_0_0_ap_fixed_16_6_5_3_0_config8_s'.
# WARNING: [SYN 201-103] Legalizing function name 'softmax_stable<ap_fixed,ap_fixed<16,6,5,3,0>,softmax_config10>' to 'softmax_stable_ap_fixed_ap_fixed_16_6_5_3_0_softmax_config10_s'.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-42] -- Implementing module 'dense_latency_ap_fixed_8_2_5_3_0_ap_fixed_16_6_5_3_0_config2_s'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [SCHED 204-11] Starting scheduling ...
# INFO: [SCHED 204-61] Pipelining function 'dense_latency<ap_fixed<8, 2, 5, 3, 0>, ap_fixed<16, 6, 5, 3, 0>, config2>'.
# INFO: [HLS 200-1470] Pipelining result : Target II = NA, Final II = 1, Depth = 7, function 'dense_latency<ap_fixed<8, 2, 5, 3, 0>, ap_fixed<16, 6, 5, 3, 0>, config2>'
# WARNING: [HLS 200-871] Estimated clock period (3.1585ns) exceeds the target (target clock period: 3.33ns, clock uncertainty: 0.416ns, effective delay budget: 2.914ns).
# Resolution: For help on HLS 200-871 see www.xilinx.com/cgi-bin/docs/rdoc?v=2022.1;t=hls+guidance;d=200-871.html
# WARNING: [HLS 200-1016] The critical path in module 'dense_latency_ap_fixed_8_2_5_3_0_ap_fixed_16_6_5_3_0_config2_s' consists of the following:	'sub' operation ('sub_ln1319_484') [847]  (0 ns)
# 	'sub' operation ('r.V') [851]  (3.16 ns)
#
# Resolution: For help on HLS 200-1016 see www.xilinx.com/cgi-bin/docs/rdoc?v=2022.1;t=hls+guidance;d=200-1016.html
# INFO: [SCHED 204-11] Finished scheduling.
# INFO: [HLS 200-111] Finished Scheduling: CPU user time: 1.05 seconds. CPU system time: 0.07 seconds. Elapsed time: 1.12 seconds; current allocated memory: 1.085 GB.
# INFO: [BIND 205-100] Starting micro-architecture generation ...
# INFO: [BIND 205-101] Performing variable lifetime analysis.
# INFO: [BIND 205-101] Exploring resource sharing.
# INFO: [BIND 205-101] Binding ...
# INFO: [BIND 205-100] Starting global binding ...
# INFO: [BIND 205-100] Finished micro-architecture generation.
# INFO: [HLS 200-111] Finished Binding: CPU user time: 1.13 seconds. CPU system time: 0.02 seconds. Elapsed time: 1.14 seconds; current allocated memory: 1.087 GB.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-42] -- Implementing module 'relu_ap_fixed_16_6_5_3_0_ap_ufixed_8_0_4_0_0_relu_config4_s'
# ...
# INFO: [RTGEN 206-100] Generating core module 'mul_8s_8ns_16_3_0': 3 instance(s).
# INFO: [RTGEN 206-100] Generating core module 'mul_8s_8s_16_3_0': 4 instance(s).
# INFO: [RTGEN 206-100] Finished creating RTL model for 'dense_latency_ap_fixed_8_2_5_3_0_ap_fixed_16_6_5_3_0_config2_s'.
# INFO: [HLS 200-111] Finished Creating RTL model: CPU user time: 6.42 seconds. CPU system time: 0.04 seconds. Elapsed time: 6.46 seconds; current allocated memory: 1.167 GB.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-10] -- Generating RTL for module 'relu_ap_fixed_16_6_5_3_0_ap_ufixed_8_0_4_0_0_relu_config4_s'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [RTGEN 206-100] Finished creating RTL model for 'relu_ap_fixed_16_6_5_3_0_ap_ufixed_8_0_4_0_0_relu_config4_s'.
# INFO: [HLS 200-111] Finished Creating RTL model: CPU user time: 4.01 seconds. CPU system time: 0.08 seconds. Elapsed time: 4.09 seconds; current allocated memory: 1.197 GB.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-10] -- Generating RTL for module 'dense_latency_ap_ufixed_8_0_4_0_0_ap_fixed_16_6_5_3_0_config5_s'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [RTGEN 206-104] Estimated max fanout for 'dense_latency_ap_ufixed_8_0_4_0_0_ap_fixed_16_6_5_3_0_config5_s' is 13384 from HDL expression: ((1'b1 == ap_ce_reg) & (1'b0 == ap_block_pp0_stage0_11001))
# INFO: [RTGEN 206-100] Generating core module 'mul_8ns_5ns_12_3_0': 22 instance(s).
# INFO: [RTGEN 206-100] Generating core module 'mul_8ns_5s_13_3_0': 12 instance(s).
# INFO: [RTGEN 206-100] Generating core module 'mul_8ns_6ns_13_3_0': 42 instance(s).
# INFO: [RTGEN 206-100] Generating core module 'mul_8ns_6s_14_3_0': 26 instance(s).
# INFO: [RTGEN 206-100] Generating core module 'mul_8ns_7ns_14_3_0': 29 instance(s).
# INFO: [RTGEN 206-100] Generating core module 'mul_8ns_7s_15_3_0': 21 instance(s).
# INFO: [RTGEN 206-100] Generating core module 'mul_8ns_8ns_15_3_0': 23 instance(s).
# INFO: [RTGEN 206-100] Generating core module 'mul_8ns_8s_16_3_0': 7 instance(s).
# INFO: [RTGEN 206-100] Finished creating RTL model for 'dense_latency_ap_ufixed_8_0_4_0_0_ap_fixed_16_6_5_3_0_config5_s'.
# INFO: [HLS 200-111] Finished Creating RTL model: CPU user time: 2.62 seconds. CPU system time: 0.04 seconds. Elapsed time: 2.67 seconds; current allocated memory: 1.244 GB.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-10] -- Generating RTL for module 'relu_ap_fixed_16_6_5_3_0_ap_ufixed_8_0_4_0_0_relu_config7_s'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [RTGEN 206-100] Finished creating RTL model for 'relu_ap_fixed_16_6_5_3_0_ap_ufixed_8_0_4_0_0_relu_config7_s'.
# INFO: [HLS 200-111] Finished Creating RTL model: CPU user time: 9.49 seconds. CPU system time: 0.15 seconds. Elapsed time: 9.66 seconds; current allocated memory: 1.312 GB.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-10] -- Generating RTL for module 'dense_latency_ap_ufixed_8_0_4_0_0_ap_fixed_16_6_5_3_0_config8_s'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [RTGEN 206-104] Estimated max fanout for 'dense_latency_ap_ufixed_8_0_4_0_0_ap_fixed_16_6_5_3_0_config8_s' is 5066 from HDL expression: ((1'b0 == ap_block_pp0_stage0_11001) & (1'b1 == ap_ce_reg))
# INFO: [RTGEN 206-100] Generating core module 'mul_8ns_5ns_12_3_0': 4 instance(s).
# INFO: [RTGEN 206-100] Generating core module 'mul_8ns_5s_13_3_0': 7 instance(s).
# INFO: [RTGEN 206-100] Generating core module 'mul_8ns_6ns_13_3_0': 19 instance(s).
# INFO: [RTGEN 206-100] Generating core module 'mul_8ns_6s_14_3_0': 10 instance(s).
# INFO: [RTGEN 206-100] Generating core module 'mul_8ns_7ns_14_3_0': 13 instance(s).
# INFO: [RTGEN 206-100] Generating core module 'mul_8ns_7s_15_3_0': 8 instance(s).
# INFO: [RTGEN 206-100] Generating core module 'mul_8ns_8ns_15_3_0': 3 instance(s).
# INFO: [RTGEN 206-100] Generating core module 'mul_8ns_8s_16_3_0': 6 instance(s).
# INFO: [RTGEN 206-100] Finished creating RTL model for 'dense_latency_ap_ufixed_8_0_4_0_0_ap_fixed_16_6_5_3_0_config8_s'.
# INFO: [HLS 200-111] Finished Creating RTL model: CPU user time: 3.15 seconds. CPU system time: 0.05 seconds. Elapsed time: 3.22 seconds; current allocated memory: 1.336 GB.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-10] -- Generating RTL for module 'softmax_stable_ap_fixed_ap_fixed_16_6_5_3_0_softmax_config10_s'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [SYN 201-210] Renamed object name 'softmax_stable_ap_fixed_ap_fixed_16_6_5_3_0_softmax_config10_s_exp_table_ROM_AUTO_1R' to 'softmax_stable_ap_fixed_ap_fixed_16_6_5_3_0_softmax_config10_s_exp_table_ROM_bkb' due to the length limit 80
# INFO: [SYN 201-210] Renamed object name 'softmax_stable_ap_fixed_ap_fixed_16_6_5_3_0_softmax_config10_s_invert_table_ROM_AUTO_1R' to 'softmax_stable_ap_fixed_ap_fixed_16_6_5_3_0_softmax_config10_s_invert_table_Rcud' due to the length limit 80
# INFO: [HLS 200-1030] Apply Unified Pipeline Control on module 'softmax_stable_ap_fixed_ap_fixed_16_6_5_3_0_softmax_config10_s' pipeline 'softmax_stable<ap_fixed,ap_fixed<16,6,5,3,0>,softmax_config10>' pipeline type 'function pipeline'
# INFO: [RTGEN 206-100] Generating core module 'mul_mul_18s_18s_30_4_1': 10 instance(s).
# INFO: [RTGEN 206-100] Finished creating RTL model for 'softmax_stable_ap_fixed_ap_fixed_16_6_5_3_0_softmax_config10_s'.
# INFO: [HLS 200-111] Finished Creating RTL model: CPU user time: 3.53 seconds. CPU system time: 0.07 seconds. Elapsed time: 3.61 seconds; current allocated memory: 1.363 GB.
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [HLS 200-10] -- Generating RTL for module 'myproject'
# INFO: [HLS 200-10] ----------------------------------------------------------------
# INFO: [RTGEN 206-500] Setting interface mode on port 'myproject/fc1_input' to 'ap_none'.
# INFO: [RTGEN 206-500] Setting interface mode on port 'myproject/layer10_out_0' to 'ap_vld'.
# INFO: [RTGEN 206-500] Setting interface mode on port 'myproject/layer10_out_1' to 'ap_vld'.
# INFO: [RTGEN 206-500] Setting interface mode on port 'myproject/layer10_out_2' to 'ap_vld'.
# INFO: [RTGEN 206-500] Setting interface mode on port 'myproject/layer10_out_3' to 'ap_vld'.
# INFO: [RTGEN 206-500] Setting interface mode on port 'myproject/layer10_out_4' to 'ap_vld'.
# INFO: [RTGEN 206-500] Setting interface mode on port 'myproject/layer10_out_5' to 'ap_vld'.
# INFO: [RTGEN 206-500] Setting interface mode on port 'myproject/layer10_out_6' to 'ap_vld'.
# INFO: [RTGEN 206-500] Setting interface mode on port 'myproject/layer10_out_7' to 'ap_vld'.
# INFO: [RTGEN 206-500] Setting interface mode on port 'myproject/layer10_out_8' to 'ap_vld'.
# INFO: [RTGEN 206-500] Setting interface mode on port 'myproject/layer10_out_9' to 'ap_vld'.
# INFO: [RTGEN 206-500] Setting interface mode on function 'myproject' to 'ap_ctrl_hs'.
# INFO: [HLS 200-1030] Apply Unified Pipeline Control on module 'myproject' pipeline 'myproject' pipeline type 'function pipeline'
# INFO: [RTGEN 206-104] Estimated max fanout for 'myproject' is 15920 from HDL expression: ((1'b0 == ap_block_pp0_stage0_11001_ignoreCallOp116) & (1'b1 == ap_CS_fsm_pp0_stage0))
# INFO: [RTGEN 206-100] Finished creating RTL model for 'myproject'.
# INFO: [HLS 200-111] Finished Creating RTL model: CPU user time: 0.94 seconds. CPU system time: 0.02 seconds. Elapsed time: 0.94 seconds; current allocated memory: 1.383 GB.
# INFO: [RTMG 210-279] Implementing memory 'myproject_softmax_stable_ap_fixed_ap_fixed_16_6_5_3_0_softmax_config10_s_exp_table_ROM_bkb' using auto ROMs.
# INFO: [RTMG 210-279] Implementing memory 'myproject_softmax_stable_ap_fixed_ap_fixed_16_6_5_3_0_softmax_config10_s_invert_table_Rcud' using auto ROMs.
# INFO: [HLS 200-111] Finished Generating all RTL models: CPU user time: 11.2 seconds. CPU system time: 0.04 seconds. Elapsed time: 11.25 seconds; current allocated memory: 1.400 GB.
# INFO: [HLS 200-111] Finished Updating report files: CPU user time: 1.1 seconds. CPU system time: 0.01 seconds. Elapsed time: 1.12 seconds; current allocated memory: 1.421 GB.
# INFO: [VHDL 208-304] Generating VHDL RTL for myproject.
# INFO: [VLOG 209-307] Generating Verilog RTL for myproject.
# INFO: [HLS 200-789] **** Estimated Fmax: 309.02 MHz
# INFO: [HLS 200-111] Finished Command csynth_design CPU user time: 130.96 seconds. CPU system time: 3.05 seconds. Elapsed time: 133.3 seconds; current allocated memory: -38.148 MB.
# ***** C/RTL SYNTHESIS COMPLETED IN 0h2m13s *****
# INFO: [HLS 200-112] Total CPU user time: 133.59 seconds. Total CPU system time: 3.82 seconds. Total elapsed time: 135.37 seconds; peak allocated memory: 1.458 GB.
# INFO: [Common 17-206] Exiting vitis_hls at Mon Sep 23 15:39:03 2024...
# ... quantizing model
# ... quantizing model
# ... quantizing model
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Interpreting Sequential
# Topology:
# Layer name: fc1_input, layer type: InputLayer, input shapes: [[None, 14]], output shape: [None, 14]
# Layer name: fc1, layer type: QDense, input shapes: [[None, 14]], output shape: [None, 41]
# Layer name: relu1, layer type: Activation, input shapes: [[None, 41]], output shape: [None, 41]
# Layer name: fc2, layer type: QDense, input shapes: [[None, 41]], output shape: [None, 14]
# Layer name: relu2, layer type: Activation, input shapes: [[None, 14]], output shape: [None, 14]
# Layer name: fc3, layer type: QDense, input shapes: [[None, 14]], output shape: [None, 25]
# Layer name: softmax, layer type: Softmax, input shapes: [[None, 25]], output shape: [None, 25]
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Interpreting Sequential
# Topology:
# Layer name: fc1_input, layer type: InputLayer, input shapes: [[None, 14]], output shape: [None, 14]
# Layer name: fc1, layer type: QDense, input shapes: [[None, 14]], output shape: [None, 41]
# Layer name: relu1, layer type: Activation, input shapes: [[None, 41]], output shape: [None, 41]
# Layer name: fc2, layer type: QDense, input shapes: [[None, 41]], output shape: [None, 14]
# Layer name: relu2, layer type: Activation, input shapes: [[None, 14]], output shape: [None, 14]
# Layer name: fc3, layer type: QDense, input shapes: [[None, 14]], output shape: [None, 25]
# Layer name: softmax, layer type: Softmax, input shapes: [[None, 25]], output shape: [None, 25]
# Creating HLS model
# Writing HLS project
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Done
#
# ****** Vitis HLS - High-Level Synthesis from C, C++ and OpenCL v2022.1 (64-bit)
#   **** SW Build 3526262 on Mon Apr 18 15:47:01 MDT 2022
#   **** IP Build 3524634 on Mon Apr 18 20:55:01 MDT 2022
#     ** Copyright 1986-2022 Xilinx, Inc. All Rights Reserved.
#
# source /tools/Xilinx/Vitis_HLS/2022.1/scripts/vitis_hls/hls.tcl -notrace
# INFO: [HLS 200-10] Running '/tools/Xilinx/Vitis_HLS/2022.1/bin/unwrapped/lnx64.o/vitis_hls'
# INFO: [HLS 200-10] For user 'dmitsas' on host 'skylla' (Linux_x86_64 version 5.4.0-196-generic) on Mon Sep 23 15:39:11 EEST 2024
# INFO: [HLS 200-10] On os Ubuntu 20.04 LTS
# INFO: [HLS 200-10] In directory '/home/dmitsas/Downloads/dse/testing/estimator_testing/results_DSP/results/prec_8/reuse_1/model_1/hls4ml_prj'
# Sourcing Tcl script 'build_prj_orig.tcl'
# INFO: [HLS 200-1510] Running: open_project myproject_prj
# INFO: [HLS 200-10] Creating and opening project '/home/dmitsas/Downloads/dse/testing/estimator_testing/results_DSP/results/prec_8/reuse_1/model_1/hls4ml_prj/myproject_prj'.
# INFO: [HLS 200-1510] Running: set_top myproject
# INFO: [HLS 200-1510] Running: add_files firmware/myproject.cpp -cflags -std=c++0x
# INFO: [HLS 200-10] Adding design file 'firmware/myproject.cpp' to the project
# INFO: [HLS 200-1510] Running: add_files -tb myproject_test.cpp -cflags -std=c++0x
# INFO: [HLS 200-10] Adding test bench file 'myproject_test.cpp' to the project
# INFO: [HLS 200-1510] Running: add_files -tb firmware/weights
# INFO: [HLS 200-10] Adding test bench file 'firmware/weights' to the project
# INFO: [HLS 200-1510] Running: add_files -tb tb_data
# INFO: [HLS 200-10] Adding test bench file 'tb_data' to the project
# INFO: [HLS 200-1510] Running: open_solution solution1
# INFO: [HLS 200-10] Creating and opening solution '/home/dmitsas/Downloads/dse/testing/estimator_testing/results_DSP/results/prec_8/reuse_1/model_1/hls4ml_prj/myproject_prj/solution1'.
# INFO: [HLS 200-1505] Using default flow_target 'vivado'
# Resolution: For help on HLS 200-1505 see www.xilinx.com/cgi-bin/docs/rdoc?v=2022.1;t=hls+guidance;d=200-1505.html
# INFO: [HLS 200-435] Setting 'open_solution -flow_target vivado' configuration: config_interface -m_axi_latency=0
# INFO: [HLS 200-1510] Running: config_array_partition -maximum_size 4096
# INFO: [XFORM 203-101] Allowed max sub elements number after partition is 4096.
# ERROR: [HLS 200-642] The 'config_array_partition -maximum_size' command is not supported.
# INFO: [HLS 200-1510] Running: config_compile -name_max_length 80
# INFO: [XFORM 203-1161] The maximum of name length is set to 80.
# INFO: [HLS 200-1510] Running: set_part xc7z007s-clg225-2
# INFO: [HLS 200-1611] Setting target device to 'xc7z007s-clg225-2'
# INFO: [XFORM 203-1161] The maximum of name length is set to 80.
# INFO: [HLS 200-1510] Running: config_schedule -enable_dsp_full_reg=false
# INFO: [HLS 200-1510] Running: config_op mul -impl dsp
# INFO: [HLS 200-1445] Configure operator 'mul' with implementation style 'dsp'.
# INFO: [HLS 200-1510] Running: create_clock -period 3.33 -name default
# INFO: [SYN 201-201] Setting up clock 'default' with a period of 3.33ns.
# INFO: [HLS 200-1510] Running: set_clock_uncertainty 12.5% default
# INFO: [SYN 201-201] Setting up clock 'default' with an uncertainty of 0.416ns.
# ***** C/RTL SYNTHESIS *****
# INFO: [HLS 200-1510] Running: csynth_design
# INFO: [HLS 200-111] Finished File checks and directory preparation: CPU user time: 0.01 seconds. CPU system time: 0 seconds. Elapsed time: 0.01 seconds; current allocated memory: 1.458 GB.
# INFO: [HLS 200-10] Analyzing design file 'firmware/myproject.cpp' ...
# WARNING: [HLS 207-5555] Unsupported interface port data type in '#pragma HLS interface ap_vld' (firmware/myproject.cpp:14:45)
# WARNING: [HLS 207-5292] unused parameter 'keep' (firmware/nnet_utils/nnet_helpers.h:285:99)
# WARNING: [HLS 207-5292] unused parameter 'data' (firmware/nnet_utils/nnet_code_gen.h:11:36)
# WARNING: [HLS 207-5292] unused parameter 'buffer' (firmware/nnet_utils/nnet_code_gen.h:12:36)
# WARNING: [HLS 207-5292] unused parameter 'partition' (firmware/nnet_utils/nnet_code_gen.h:13:44)
# WARNING: [HLS 207-5292] unused parameter 'data' (firmware/nnet_utils/nnet_code_gen.h:21:24)
# WARNING: [HLS 207-5292] unused parameter 'buffer' (firmware/nnet_utils/nnet_code_gen.h:22:24)
# WARNING: [HLS 207-5292] unused parameter 'partition' (firmware/nnet_utils/nnet_code_gen.h:23:32)
# INFO: [HLS 200-111] Finished Source Code Analysis and Preprocessing: CPU user time: 9.49 seconds. CPU system time: 0.85 seconds. Elapsed time: 9.49 seconds; current allocated memory: 464.637 MB.
# INFO: [HLS 200-777] Using interface defaults for 'Vivado' flow target.
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x7f419a0e1f90>>
# Traceback (most recent call last):
#   File "/home/dmitsas/anaconda3/envs/hls4ml-tutorial/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 775, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(
# KeyboardInterrupt:
#
# KeyboardInterrupt

# %%
for prec in range(8,1,-1):
    for reuse in rf_range:
        filename = "./final_results/results/prec_" + str(prec) + "/reuse_" + str(reuse) + "/model_"
        for k in range(layer_num+1):
            os.system("rm -r " + filename + str(k) + "/hls4ml_prj/myproject_prj/solution1/.autopilot")
# Out:
# rm: cannot remove './final_results/results/prec_8/reuse_1/model_0/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_1/model_1/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_1/model_2/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_1/model_3/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_1/model_4/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_1/model_5/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_1/model_6/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_1/model_7/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_1/model_8/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_1/model_9/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_1/model_10/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_1/model_11/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_1/model_12/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_1/model_13/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_1/model_14/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_1/model_15/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_1/model_16/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_1/model_17/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_1/model_18/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_1/model_19/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_1/model_20/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_1/model_21/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_1/model_22/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_1/model_23/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_1/model_24/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_1/model_25/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_1/model_26/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_1/model_27/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_1/model_28/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_1/model_29/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_1/model_30/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_1/model_31/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_1/model_32/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_1/model_33/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_1/model_34/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_1/model_35/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_1/model_36/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_1/model_37/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_1/model_38/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_1/model_39/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_1/model_40/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_1/model_41/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_1/model_42/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_1/model_43/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_1/model_44/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_1/model_45/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_1/model_46/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_1/model_47/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_1/model_48/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_1/model_49/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_1/model_50/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_2/model_0/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_2/model_1/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_2/model_2/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_2/model_3/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_2/model_4/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_2/model_5/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_2/model_6/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_2/model_7/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_2/model_8/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_2/model_9/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_2/model_10/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_2/model_11/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_2/model_12/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_2/model_13/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_2/model_14/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_2/model_15/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_2/model_16/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_2/model_17/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_2/model_18/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_2/model_19/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_2/model_20/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_2/model_21/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_2/model_22/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_2/model_23/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_2/model_24/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_2/model_25/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_2/model_26/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_2/model_27/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_2/model_28/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_2/model_29/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_2/model_30/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_2/model_31/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_2/model_32/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_2/model_33/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_2/model_34/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_2/model_35/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_2/model_36/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_2/model_37/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_2/model_38/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_2/model_39/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_2/model_40/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_2/model_41/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_2/model_42/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_2/model_43/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_2/model_44/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_2/model_45/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_2/model_46/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_2/model_47/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_2/model_48/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_2/model_49/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_2/model_50/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_3/model_0/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_3/model_1/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_3/model_2/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_3/model_3/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_3/model_4/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_3/model_5/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_3/model_6/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_3/model_7/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_3/model_8/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_3/model_9/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_3/model_10/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_3/model_11/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_3/model_12/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_3/model_13/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_3/model_14/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_3/model_15/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_3/model_16/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_3/model_17/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_3/model_18/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_3/model_19/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_3/model_20/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_3/model_21/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_3/model_22/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_3/model_23/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_3/model_24/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_3/model_25/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_3/model_26/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_3/model_27/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_3/model_28/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_3/model_29/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_3/model_30/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_3/model_31/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_3/model_32/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_3/model_33/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_3/model_34/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_3/model_35/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_3/model_36/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_3/model_37/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_3/model_38/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_3/model_39/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_3/model_40/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_3/model_41/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_3/model_42/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_3/model_43/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_3/model_44/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_3/model_45/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_3/model_46/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_3/model_47/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_3/model_48/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_3/model_49/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_3/model_50/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_4/model_0/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_4/model_1/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_4/model_2/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_4/model_3/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_4/model_4/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_4/model_5/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_4/model_6/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_4/model_7/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_4/model_8/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_4/model_9/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_4/model_10/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_4/model_11/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_4/model_12/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_4/model_13/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_4/model_14/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_4/model_15/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_4/model_16/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_4/model_17/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_4/model_18/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_4/model_19/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_4/model_20/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_4/model_21/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_4/model_22/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_4/model_23/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_4/model_24/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_4/model_25/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_4/model_26/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_4/model_27/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_4/model_28/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_4/model_29/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_4/model_30/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_4/model_31/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_4/model_32/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_4/model_33/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_4/model_34/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_4/model_35/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_4/model_36/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_4/model_37/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_4/model_38/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_4/model_39/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_4/model_40/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_4/model_41/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_4/model_42/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_4/model_43/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_4/model_44/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_4/model_45/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_4/model_46/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_4/model_47/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_4/model_48/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_4/model_49/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_4/model_50/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_10/model_0/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_10/model_1/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_10/model_2/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_10/model_3/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_10/model_4/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_10/model_5/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_10/model_6/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_10/model_7/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_10/model_8/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_10/model_9/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_10/model_10/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_10/model_11/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_10/model_12/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_10/model_13/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_10/model_14/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_10/model_15/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_10/model_16/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_10/model_17/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_10/model_18/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_10/model_19/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_10/model_20/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_10/model_21/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_10/model_22/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_10/model_23/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_10/model_24/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_10/model_25/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_10/model_26/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_10/model_27/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_10/model_28/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_10/model_29/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_10/model_30/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_10/model_31/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_10/model_32/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_10/model_33/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_10/model_34/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_10/model_35/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_10/model_36/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_10/model_37/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_10/model_38/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_10/model_39/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_10/model_40/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_10/model_41/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_10/model_42/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_10/model_43/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_10/model_44/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_10/model_45/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_10/model_46/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_10/model_47/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_10/model_48/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_10/model_49/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_8/reuse_10/model_50/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_1/model_0/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_1/model_1/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_1/model_2/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_1/model_3/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_1/model_4/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_1/model_5/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_1/model_6/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_1/model_7/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_1/model_8/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_1/model_9/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_1/model_10/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_1/model_11/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_1/model_12/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_1/model_13/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_1/model_14/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_1/model_15/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_1/model_16/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_1/model_17/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_1/model_18/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_1/model_19/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_1/model_20/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_1/model_21/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_1/model_22/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_1/model_23/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_1/model_24/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_1/model_25/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_1/model_26/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_1/model_27/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_1/model_28/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_1/model_29/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_1/model_30/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_1/model_31/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_1/model_32/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_1/model_33/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_1/model_34/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_1/model_35/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_1/model_36/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_1/model_37/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_1/model_38/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_1/model_39/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_1/model_40/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_1/model_41/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_1/model_42/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_1/model_43/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_1/model_44/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_1/model_45/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_1/model_46/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_1/model_47/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_1/model_48/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_1/model_49/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_1/model_50/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_2/model_0/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_2/model_1/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_2/model_2/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_2/model_3/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_2/model_4/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_2/model_5/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_2/model_6/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_2/model_7/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_2/model_8/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_2/model_9/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_2/model_10/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_2/model_11/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_2/model_12/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_2/model_13/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_2/model_14/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_2/model_15/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_2/model_16/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_2/model_17/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_2/model_18/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_2/model_19/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_2/model_20/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_2/model_21/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_2/model_22/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_2/model_23/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_2/model_24/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_2/model_25/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_2/model_26/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_2/model_27/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_2/model_28/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_2/model_29/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_2/model_30/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_2/model_31/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_2/model_32/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_7/reuse_2/model_33/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# ...
# rm: cannot remove './final_results/results/prec_2/reuse_3/model_40/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_3/model_41/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_3/model_42/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_3/model_43/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_3/model_44/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_3/model_45/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_3/model_46/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_3/model_47/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_3/model_48/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_3/model_49/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_3/model_50/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_4/model_0/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_4/model_1/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_4/model_2/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_4/model_3/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_4/model_4/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_4/model_5/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_4/model_6/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_4/model_7/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_4/model_8/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_4/model_9/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_4/model_10/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_4/model_11/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_4/model_12/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_4/model_13/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_4/model_14/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_4/model_15/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_4/model_16/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_4/model_17/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_4/model_18/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_4/model_19/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_4/model_20/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_4/model_21/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_4/model_22/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_4/model_23/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_4/model_24/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_4/model_25/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_4/model_26/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_4/model_27/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_4/model_28/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_4/model_29/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_4/model_30/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_4/model_31/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_4/model_32/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_4/model_33/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_4/model_34/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_4/model_35/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_4/model_36/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_4/model_37/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_4/model_38/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_4/model_39/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_4/model_40/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_4/model_41/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_4/model_42/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_4/model_43/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_4/model_44/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_4/model_45/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_4/model_46/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_4/model_47/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_4/model_48/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_4/model_49/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_4/model_50/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_10/model_0/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_10/model_1/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_10/model_2/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_10/model_3/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_10/model_4/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_10/model_5/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_10/model_6/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_10/model_7/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_10/model_8/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_10/model_9/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_10/model_10/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_10/model_11/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_10/model_12/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_10/model_13/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_10/model_14/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_10/model_15/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_10/model_16/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_10/model_17/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_10/model_18/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_10/model_19/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_10/model_20/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_10/model_21/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_10/model_22/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_10/model_23/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_10/model_24/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_10/model_25/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_10/model_26/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_10/model_27/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_10/model_28/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_10/model_29/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_10/model_30/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_10/model_31/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_10/model_32/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_10/model_33/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_10/model_34/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_10/model_35/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_10/model_36/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_10/model_37/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_10/model_38/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_10/model_39/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_10/model_40/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_10/model_41/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_10/model_42/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_10/model_43/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_10/model_44/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_10/model_45/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_10/model_46/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_10/model_47/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_10/model_48/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_10/model_49/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
# rm: cannot remove './final_results/results/prec_2/reuse_10/model_50/hls4ml_prj/myproject_prj/solution1/.autopilot': No such file or directory
